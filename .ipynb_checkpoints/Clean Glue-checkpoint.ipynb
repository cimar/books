# %% [markdown]
# 1. Read all the TSV files into an array, write a function to extract the title and authors data
# 2. Go through each TSV and use title and authors to search the OCLC for OWI number
# 3. Go through each OWI and get:
#     3.1 Earliest year published
#     3.2 Holdings
#     3.3 For OWI with the most holdings: VIAF -> Genders
#     3.5 For each OWI where "book" in .get("format")
#     Make Genders -> DDC dict, add to it manually
# 4. Make a dict of TITLE/AUTHOR STRING -> OWI, YEAR_PUBLISHED, GENDER(S), TOP_DDC, FAST_LIST?

# %%
import csv, os
from datetime import datetime
f_filen = "tabula-1963-03-17.tsv"
nf_filen = "tabula-1963-03-17-nf.tsv"
data_i = 2 #How far into the tsv file the data shows up...
fields = ['rank','title+author','rank_last_week','weeks_on_list']
stop_words_authors = ["Others"]

# %% [markdown]
# # Read the Data In

# %%
def empty(row):
    if row[0]=="":
        return True
    return False 

def extract_date(datestr):
    try:
        date = datetime.strptime(datestr[0],'%B %d, %Y')
    except ValueError:
        try:
            date = datetime.strptime(datestr[0],'%B %d,%Y')
        except ValueError:
            datestr = input("Enter the date in %B %d, %Y format: ")
            date = datetime.strptime(datestr,'%B %d, %Y')
    return date

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

def header(row):
    if is_number(row[0]):
        return False
    else:
        return True
    
def read_tsv(name):
    i = 0
    arr = []
    date = ""
    with open(name) as csvfile:
        reader = csv.reader(csvfile, delimiter='\t')
        for row in reader:
            if (header(row)) & (not empty(row)) & (i>data_i):
                return arr
            if i ==0 :
                date = extract_date([row[1]])
            if ((i > data_i) & (not empty(row))):
                arr.append([date]+row)
            i = i+1
        return arr
    
def read_folder(folderpath):
    arr = []
    for f in os.listdir(folderpath):
        commasv = read_tsv(folderpath+f)
        arr = arr+commasv
    return arr

eighty_path = "1980/"
eighty = read_folder(eighty_path)
for x in eighty[0:100]:
    print x
# Out:
# [datetime.datetime(1980, 2, 3, 0, 0), '1', "SMILEY'S PEOPLE, by John le Carr\xc3\xa9. (Knopf, $10.95.) The great British spy has", '1', '7']
# [datetime.datetime(1980, 2, 3, 0, 0), '2', "THE DEVIL'S ALTERNATIVE, by Frederick Forsyth. (Viking, $12.95.) Countdown", '--', '1']
# [datetime.datetime(1980, 2, 3, 0, 0), '3', 'JAILBIRD, by Kurt Vonnegut. (Delacorte/Seymour Lawrence, $9.95.) From World', '2', '20']
# [datetime.datetime(1980, 2, 3, 0, 0), '4', 'TRIPLE, by Ken Follett. (Arbor House, $10.95.) Power play between intelligence', '4', '22']
# [datetime.datetime(1980, 2, 3, 0, 0), '5', 'MEMORIES OF ANOTHER DAY, by Harold Robbins. (Simon & Schuster, $10.95.)', '5', '12']
# [datetime.datetime(1980, 2, 3, 0, 0), '6', 'THE ESTABLISHMENT, by Howard Fast. (Houghton Mifflin, $11.95.) The', '7', '17']
# [datetime.datetime(1980, 2, 3, 0, 0), '7', 'PRINCESS DAISY, by Judith Krantz. (Crown, $12.95.) The fight for survival in the', '--', '1']
# [datetime.datetime(1980, 2, 3, 0, 0), '8', "SOPHIE'S CHOICE, by William Styron. (Random House, $12.95.) The nature of", '6', '33']
# [datetime.datetime(1980, 2, 3, 0, 0), '9', 'THE TOP OF THE HILL, by Irwin Shaw. (Delacorte, $8.95.) A jaded New Yorker', '8', '8']
# [datetime.datetime(1980, 2, 3, 0, 0), '10', 'PORTRAITS, by Cynthia Freeman. (Arbor House, $9.95.) The Sansonitskys of "A', '14', '5']
# [datetime.datetime(1980, 2, 3, 0, 0), '11', "THE EXECUTIONER'S SONG, by Norman Mailler. (Little, Brown, $16.95.) The life", '3', '15']
# [datetime.datetime(1980, 2, 3, 0, 0), '12', 'THE DEAD ZONE, by Stephen King. (Viking, $11.95.) Johnny Smith can see the', '9', '22']
# [datetime.datetime(1980, 2, 3, 0, 0), '13', 'THE LAST ENCHANTMENT, by Mary Stewart. (Morrow, $11.95.) Further', '10', '26']
# [datetime.datetime(1980, 2, 3, 0, 0), '14', 'THE THIRD WORLD WAR: August 1985, by General Sir John Hackett and Other', '--', '35']
# [datetime.datetime(1980, 2, 3, 0, 0), '15', 'MOVIOLA, by Garson Kanin. (Simon & Schuster, $9.95.) The movie business,', '11', '2']
# [datetime.datetime(1980, 4, 27, 0, 0), '1', 'THE BOURNE IDENTITY, by Robert Ludlum. (Richard Marek, $12.95.) The', '1', '8']
# [datetime.datetime(1980, 4, 27, 0, 0), '2', 'PRINCESS DAISY, by Judith Krantz. (Crown, $12.95.) The fight for survival in the', '2', '13']
# [datetime.datetime(1980, 4, 27, 0, 0), '3', "THE DEVIL'S ALTERNATIVE, by Frederick Forsyth. (Viking, $12.95.) Countdown", '3', '13']
# [datetime.datetime(1980, 4, 27, 0, 0), '4', 'THE BLEEDING HEART, by Marilyn French. (Summit Books, $12.95.) An', '7', '5']
# [datetime.datetime(1980, 4, 27, 0, 0), '5', "SMILEY'S PEOPLE, by John le Carr\xc3\xa9. (Knopf, $10.95.) The great British spy has", '4', '19']
# [datetime.datetime(1980, 4, 27, 0, 0), '6', "WHO'S ON FIRST, by William F. Buckley Jr. (Doubleday, $9.95.) Blackford Oakes", '6', '6']
# [datetime.datetime(1980, 4, 27, 0, 0), '7', 'PORTRAITS, by Cynthia Freeman. (Arbor House, $9.95.) The Sansonitskys of "A', '5', '17']
# [datetime.datetime(1980, 4, 27, 0, 0), '8', 'NO LOVE LOST, by Helen Van Slyke. (Lippincott, $11.95.) Three New York', '--', '1']
# [datetime.datetime(1980, 4, 27, 0, 0), '9', "CREEK MARY'S BLOOD, by Dee Brown. (Holt, Rinehart & Winston, $12.95.) Four", '11', '4']
# [datetime.datetime(1980, 4, 27, 0, 0), '10', 'KANE & ABEL, by Jeffrey Archer. (Simon & Schuster, $13.95.) Battles in a', '13', '2']
# [datetime.datetime(1980, 4, 27, 0, 0), '11', "BACK BAY, by William Martin. (Crown, $12.95.) Through 200 years of Boston's", '--', '1']
# [datetime.datetime(1980, 4, 27, 0, 0), '12', 'MEMORIES OF ANOTHER DAY, by Harold Robbins. (Simon & Schuster, $10.95.)', '12', '24']
# [datetime.datetime(1980, 4, 27, 0, 0), '13', "SOPHIE'S CHOICE, by William Styron. (Random House, $12.95.) The nature of", '10', '45']
# [datetime.datetime(1980, 4, 27, 0, 0), '14', 'THE DEAD ZONE, by Stephen King. (Viking, $11.95.) Johnny Smith can see the', '--', '32']
# [datetime.datetime(1980, 4, 27, 0, 0), '15', 'HUNGRY AS THE SEA, by Wilbur Smith. (Doubleday, $9.95.) Heroism and dirty', '8', '6']
# [datetime.datetime(1980, 5, 18, 0, 0), '1', 'THE BOURNE IDENTITY, by Robert Ludlum. (Richard Marek, $12.95.) The', '1', '11']
# [datetime.datetime(1980, 5, 18, 0, 0), '2', 'PRINCESS DAISY, by Judith Krantz. (Crown, $12.95.) The fight for survival in the', '2', '16']
# [datetime.datetime(1980, 5, 18, 0, 0), '3', 'NO LOVE LOST, by Helen Van Slyke. (Lippincott, $11.95.) Three New York', '5', '4']
# [datetime.datetime(1980, 5, 18, 0, 0), '4', "THE DEVIL'S ALTERNATIVE, by Frederick Forsyth. (Viking, $12.95.) Countdown", '3', '16']
# [datetime.datetime(1980, 5, 18, 0, 0), '5', 'RANDOM WINDS, by Belva Plain. (Delacorte, $11.95.) Three generations of', '14', '2']
# [datetime.datetime(1980, 5, 18, 0, 0), '6', 'KANE & ABEL, by Jeffrey Archer. (Simon & Schuster, $13.95.) Battles in a', '6', '5']
# [datetime.datetime(1980, 5, 18, 0, 0), '7', 'THE BLEEDING HEART, by Marilyn French. (Summit Books, $12.95.) An', '4', '8']
# [datetime.datetime(1980, 5, 18, 0, 0), '8', 'PORTRAITS, by Cynthia Freeman. (Arbor House, $9.95.) The Sansonitskys of "A', '7', '20']
# [datetime.datetime(1980, 5, 18, 0, 0), '9', "SMILEY'S PEOPLE, by John le Carr\xc3\xa9. (Knopf, $10.95.) The great British spy has", '8', '22']
# [datetime.datetime(1980, 5, 18, 0, 0), '10', 'THE NINJA, by Eric Van Lustbader. (M. Evans, $12.95.) The erotic side of the', '12', '2']
# [datetime.datetime(1980, 5, 18, 0, 0), '11', "CREEK MARY'S BLOOD, by Dee Brown. (Holt, Rinehart & Winston, $12.95.) Four", '10', '7']
# [datetime.datetime(1980, 5, 18, 0, 0), '12', "WHO'S ON FIRST, by William F. Buckley Jr. (Doubleday, $9.95.) Blackford Oakes", '9', '9']
# [datetime.datetime(1980, 5, 18, 0, 0), '13', "BACK BAY, by William Martin. (Crown, $12.95.) Through 200 years of Boston's", '11', '4']
# [datetime.datetime(1980, 5, 18, 0, 0), '14', 'HUNGRY AS THE SEA, by Wilbur Smith. (Doubleday, $9.95.) Heroism and dirty', '13', '9']
# [datetime.datetime(1980, 5, 18, 0, 0), '15', "THE EXECUTIONER'S SONG, by Norman Mailler. (Little, Brown, $16.95.) The life", '--', '25']
# [datetime.datetime(1980, 6, 29, 0, 0), '1', 'THE BOURNE IDENTITY, by Robert Ludlum. (Richard Marek, $12.95.) The', '1', '17']
# [datetime.datetime(1980, 6, 29, 0, 0), '2', 'RANDOM WINDS, by Belva Plain. (Delacorte, $11.95.) Three generations of', '3', '8']
# [datetime.datetime(1980, 6, 29, 0, 0), '3', 'PRINCESS DAISY, by Judith Krantz. (Crown, $12.95.) The fight for survival in the', '2', '22']
# [datetime.datetime(1980, 6, 29, 0, 0), '4', 'THE NINJA, by Eric Van Lustbader. (M. Evans, $12.95.) The erotic side of the', '5', '8']
# [datetime.datetime(1980, 6, 29, 0, 0), '5', "INNOCENT BLOOD, by P.D. James. (Scribner's, $10.95.) A veteran whodunit", '7', '6']
# [datetime.datetime(1980, 6, 29, 0, 0), '6', 'THE SPIKE, by Arnaud de Borchgrave and Robert Moss. (Crown, $12.95.)', '10', '3']
# [datetime.datetime(1980, 6, 29, 0, 0), '7', "THE DEVIL'S ALTERNATIVE, by Frederick Forsyth. (Viking, $12.95.) Countdown", '8', '22']
# [datetime.datetime(1980, 6, 29, 0, 0), '8', 'NO LOVE LOST, by Helen Van Slyke. (Lippincott, $10.95.) Three New York', '6', '10']
# [datetime.datetime(1980, 6, 29, 0, 0), '9', 'KANE & ABEL, by Jeffrey Archer. (Simon & Schuster, $13.95.) Battles in a', '4', '11']
# [datetime.datetime(1980, 6, 29, 0, 0), '10', 'MAN, WOMAN AND CHILD, by Erich Segal. (Harper & Row, $9.95.) A perfect', '--', '1']
# [datetime.datetime(1980, 6, 29, 0, 0), '11', 'DOCTOR FISCHER OF GENEVA OR THE BOMB PARTY, by Graham Greene.', '--', '1']
# [datetime.datetime(1980, 6, 29, 0, 0), '12', 'THE BLEEDING HEART, by Marilyn French. (Summit Books, $12.95.) An', '9', '14']
# [datetime.datetime(1980, 6, 29, 0, 0), '13', 'RAGE OF ANGELS, by Sidney Sheldon. (Morrow, $12.95.) An idealistic young', '--', '1']
# [datetime.datetime(1980, 6, 29, 0, 0), '14', 'SINS OF THE FATHERS, by Susan Howatch. (Simon & Schuster, $13.95.)', '--', '1']
# [datetime.datetime(1980, 6, 29, 0, 0), '15', 'PORTRAITS, by Cynthia Freeman. (Arbor House, $11.95.) A New York Lower', '11', '26']
# [datetime.datetime(1980, 1, 27, 0, 0), '1', "SMILEY'S PEOPLE, by John le Carr\xc3\xa9. (Knopf, $10.95.) The great British spy has", '1', '6']
# [datetime.datetime(1980, 1, 27, 0, 0), '2', 'JAILBIRD, by Kurt Vonnegut. (Delacorte/Seymour Lawrence, $9.95.) From World', '2', '19']
# [datetime.datetime(1980, 1, 27, 0, 0), '3', "THE EXECUTIONER'S SONG, by Norman Mailler. (Little, Brown, $16.95.) The life", '7', '14']
# [datetime.datetime(1980, 1, 27, 0, 0), '4', 'TRIPLE, by Ken Follett. (Arbor House, $10.95.) Power play between intelligence', '3', '21']
# [datetime.datetime(1980, 1, 27, 0, 0), '5', 'MEMORIES OF ANOTHER DAY, by Harold Robbins. (Simon & Schuster, $10.95.)', '4', '11']
# [datetime.datetime(1980, 1, 27, 0, 0), '6', "SOPHIE'S CHOICE, by William Styron. (Random House, $12.95.) The nature of", '8', '32']
# [datetime.datetime(1980, 1, 27, 0, 0), '7', 'THE ESTABLISHMENT, by Howard Fast. (Houghton Mifflin, $11.95.) The', '6', '16']
# [datetime.datetime(1980, 1, 27, 0, 0), '8', 'THE TOP OF THE HILL, by Irwin Shaw. (Delacorte, $8.95.) A jaded New Yorker', '10', '7']
# [datetime.datetime(1980, 1, 27, 0, 0), '9', 'THE DEAD ZONE, by Stephen King. (Viking, $11.95.) Johnny Smith can see the', '9', '21']
# [datetime.datetime(1980, 1, 27, 0, 0), '10', 'THE LAST ENCHANTMENT, by Mary Stewart. (Morrow, $11.95.) Further', '5', '25']
# [datetime.datetime(1980, 1, 27, 0, 0), '11', 'MOVIOLA, by Garson Kanin. (Simon & Schuster, $9.95.) The movie business,', '--', '1']
# [datetime.datetime(1980, 1, 27, 0, 0), '12', "THERE'S NO SUCH PLACE AS FAR AWAY, by Richard Bach.", '--', '25']
# [datetime.datetime(1980, 1, 27, 0, 0), '13', 'THE GREEN RIPPER, by John D. MacDonald. (Lippincott, $9.95.) Travis McGee', '13', '14']
# [datetime.datetime(1980, 1, 27, 0, 0), '14', 'PORTRAITS, by Cynthia Freeman. (Arbor House, $9.95.) The Sansonitskys of "A', '14', '4']
# [datetime.datetime(1980, 1, 27, 0, 0), '15', 'OLD LOVE, by Isaac Bashevis Singer. (Farrar, Straus & Giroux, $10.95.) New', '--', '1']
# [datetime.datetime(1980, 1, 6, 0, 0), '1', 'JAILBIRD, by Kurt Vonnegut. (Delacorte/Seymour Lawrence, $9.95.) From World', '1', '16']
# [datetime.datetime(1980, 1, 6, 0, 0), '2', 'TRIPLE, by Ken Follett. (Arbor House, $10.95.) Power play between intelligence', '2', '18']
# [datetime.datetime(1980, 1, 6, 0, 0), '3', "SMILEY'S PEOPLE, by John le Carr\xc3\xa9. (Knopf, $10.95.) The great British spy has", '6', '3']
# [datetime.datetime(1980, 1, 6, 0, 0), '4', 'THE ESTABLISHMENT, by Howard Fast. (Houghton Mifflin, $11.95.) The', '3', '13']
# [datetime.datetime(1980, 1, 6, 0, 0), '5', 'THE LAST ENCHANTMENT, by Mary Stewart. (Morrow, $11.95.) Further', '7', '22']
# [datetime.datetime(1980, 1, 6, 0, 0), '6', "THE EXECUTIONER'S SONG, by Norman Mailler. (Little, Brown, $16.95.) The life", '5', '11']
# [datetime.datetime(1980, 1, 6, 0, 0), '7', 'MEMORIES OF ANOTHER DAY, by Harold Robbins. (Simon & Schuster, $10.95.)', '4', '8']
# [datetime.datetime(1980, 1, 6, 0, 0), '8', 'THE TOP OF THE HILL, by Irwin Shaw. (Delacorte, $8.95.) A jaded New Yorker', '10', '4']
# [datetime.datetime(1980, 1, 6, 0, 0), '9', 'THE DEAD ZONE, by Stephen King. (Viking, $11.95.) Johnny Smith can see the', '9', '18']
# [datetime.datetime(1980, 1, 6, 0, 0), '10', "SOPHIE'S CHOICE, by William Styron. (Random House, $12.95.) The nature of", '12', '29']
# [datetime.datetime(1980, 1, 6, 0, 0), '11', 'THE GREEN RIPPER, by John D. MacDonald. (Lippincott, $9.95.) Travis McGee', '8', '11']
# [datetime.datetime(1980, 1, 6, 0, 0), '12', 'THE THIRD WORLD WAR: August 1985, by General Sir John Hackett and Other', '15', '32']
# [datetime.datetime(1980, 1, 6, 0, 0), '13', 'PORTRAITS, by Cynthia Freeman. (Arbor House, $9.95.) The Sansonitskys of "A', '--', '2']
# [datetime.datetime(1980, 1, 6, 0, 0), '14', "THERE'S NO SUCH PLACE AS FAR AWAY, by Richard Bach. (Delacorte/", '11', '23']
# [datetime.datetime(1980, 1, 6, 0, 0), '15', 'WAR AND REMEMBRANCE, by Herman Wouk. (Little, Brown, $15.) The Henry', '14', '62']
# [datetime.datetime(1980, 4, 20, 0, 0), '1', 'THE BOURNE IDENTITY, by Robert Ludlum. (Richard Marek, $12.95.) The', '1', '7']
# [datetime.datetime(1980, 4, 20, 0, 0), '2', 'PRINCESS DAISY, by Judith Krantz. (Crown, $12.95.) The fight for survival in the', '2', '12']
# [datetime.datetime(1980, 4, 20, 0, 0), '3', "THE DEVIL'S ALTERNATIVE, by Frederick Forsyth. (Viking, $12.95.) Countdown", '3', '12']
# [datetime.datetime(1980, 4, 20, 0, 0), '4', "SMILEY'S PEOPLE, by John le Carr\xc3\xa9. (Knopf, $10.95.) The great British spy has", '4', '18']
# [datetime.datetime(1980, 4, 20, 0, 0), '5', 'PORTRAITS, by Cynthia Freeman. (Arbor House, $9.95.) The Sansonitskys of "A', '5', '16']
# [datetime.datetime(1980, 4, 20, 0, 0), '6', "WHO'S ON FIRST, by William F. Buckley Jr. (Doubleday, $9.95.) Blackford Oakes", '6', '5']
# [datetime.datetime(1980, 4, 20, 0, 0), '7', 'THE BLEEDING HEART, by Marilyn French. (Summit Books, $12.95.) An', '7', '4']
# [datetime.datetime(1980, 4, 20, 0, 0), '8', 'HUNGRY AS THE SEA, by Wilbur Smith. (Doubleday, $9.95.) Heroism and dirty', '11', '5']
# [datetime.datetime(1980, 4, 20, 0, 0), '9', 'TRIPLE, by Ken Follett. (Arbor House, $10.95.) Power play between intelligence', '9', '33']
# [datetime.datetime(1980, 4, 20, 0, 0), '10', "SOPHIE'S CHOICE, by William Styron. (Random House, $12.95.) The nature of", '8', '44']

# %% [markdown]
# # Get Title and Author

# %%
# DONT DO IT THIS WAY parse_corrections = {}

# %%
#sample_title_auth = commasv[0][2]
#print sample_title_authR

#index into phrase to skip " by"
auth_i = 4

def parse_author_phrase(a_ph):
    authors = []
    end = len(a_ph)
    parens = a_ph.find("(")
    if parens != -1:
        end = parens-1
    auth_ph = a_ph[auth_i:end]
    if " and " in auth_ph:
        author_arr = auth_ph.split(" and ")
        for author in author_arr:
            if author[len(author)-1]=='.':
                author = author[:len(author)-1] # strip trailing period
            authors.append(author)
    else:
        author = auth_ph
        if author[len(author)-1]=='.':
            author = author[:len(author)-1] # strip trailing period
        authors.append(author)
    return authors

def title_author_pair(data_str):
    split_str = data_str.split(',')
    title = ""
    auth_ph = ""
    i=0
    t=True
    for phrase in split_str:    
        if i == 0:
            title = phrase
        else:
            if phrase.isupper() & t:
                title = title + ", "+phrase
            else:
                t = False
                auth_ph = auth_ph+phrase
        i = i+1
    authors = parse_author_phrase(auth_ph)
    return (title,authors)

for x in eighty:
    print title_author_pair(x[2])
# Out:
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('TRIPLE', ['Ken Follett'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('MOVIOLA', ['Garson Kanin'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('BACK BAY', ['William Martin'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('BACK BAY', ['William Martin'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('MAN,  WOMAN AND CHILD', ['Erich Segal'])
# ('DOCTOR FISCHER OF GENEVA OR THE BOMB PARTY', ['Graham Greene'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('TRIPLE', ['Ken Follett'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ('MOVIOLA', ['Garson Kanin'])
# ("THERE'S NO SUCH PLACE AS FAR AWAY", ['Richard Bach'])
# ('THE GREEN RIPPER', ['John D. MacDonald'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('OLD LOVE', ['Isaac Bashevis Singer'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('TRIPLE', ['Ken Follett'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('THE DEAD ZONE', ['Stephen King'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE GREEN RIPPER', ['John D. MacDonald'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("THERE'S NO SUCH PLACE AS FAR AWAY", ['Richard Bach'])
# ('WAR AND REMEMBRANCE', ['Herman Wouk'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('TRIPLE', ['Ken Follett'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('TRIPLE', ['Ken Follett'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('MOVIOLA', ['Garson Kanin'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FIRESTARTER', ['Stephen King'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('FANNY', ['Erica Jong'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('THE ORIGIN', ['Irving Stone'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('BELLEFLEUR', ['Joyce Carol Oates'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('TRIPLE', ['Ken Follett'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('THE DEAD ZONE', ['Stephen King'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('TRIPLE', ['Ken Follett'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('MOVIOLA', ['Garson Kanin'])
# ('OLD LOVE', ['Isaac Bashevis Singer'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('TRIPLE', ['Ken Follett'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('THE DEAD ZONE', ['Stephen King'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('TRIPLE', ['Ken Follett'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('WAR AND REMEMBRANCE', ['Herman Wouk'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('THE GREEN RIPPER', ['John D. MacDonald'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('SHADOW OF THE MOON', ['M.M. Kaye'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FIRESTARTER', ['Stephen King'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE ORIGIN', ['Irving Stone'])
# ('FANNY', ['Erica Jong'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('THE RING', ['Danielle Steel'])
# ('THE OLD NEIGHBORHOOD', ['Avery Corman'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('FIRESTARTER', ['Stephen King'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('THE ORIGIN', ['Irving Stone'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('BELLEFLEUR', ['Joyce Carol Oates'])
# ('THE CRADLE WILL FALL', ['Mary Higgins Clark'])
# ('FANNY', ['Erica Jong'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('GREEN MONDAY', ['Michael M. Thomas'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('WHIP HAND', ['Dick Francis'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('SOLO', ['Jack Higgins'])
# ('THE SECOND COMING', ['Walker Percy'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('THE CRADLE WILL FALL', ['Mary Higgins Clark'])
# ('GREEN MONDAY', ['Michael M. Thomas'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FIRESTARTER', ['Stephen King'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('UNFINISHED TALES', ['J.R.R. Tolkien'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('THE HIDDEN TARGET', ['Helen MacInnes'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE ORIGIN', ['Irving Stone'])
# ('MANCHU', ['Robert Elegant'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE RING', ['Danielle Steel'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('TRIPLE', ['Ken Follett'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE DEAD ZONE', ['Stephen King'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('RANDOM WINDS', ['Belva Plain'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('WHIP HAND', ['Dick Francis'])
# ('BACK BAY', ['William Martin'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FIRESTARTER', ['Stephen King'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('RAGE OF ANGELS', ['Sidney Sheldon '])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('UNFINISHED TALES', ['J.R.R. Tolkien'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('THE ORIGIN', ['Irving Stone'])
# ('THE RING', ['Danielle Steel'])
# ('FANNY', ['Erica Jong'])
# ('THE HIDDEN TARGET', ['Helen MacInnes'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('DOCTOR FISCHER OF GENEVA OR THE BOMB PARTY', ['Graham Greene'])
# ('MAN,  WOMAN AND CHILD', ['Erich Segal'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('SOLO', ['Jack Higgins'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('UNFINISHED TALES', ['J.R.R. Tolkien'])
# ('FIRESTARTER', ['Stephen King'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('ANSWER AS A MAN', ['Taylor Caldwell'])
# ('THE ORIGIN', ['Irving Stone'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE HIDDEN TARGET', ['Helen MacInnes'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('CONGO', ['Michael Crichton'])
# ('THE STORIES OF RAY BRADBURY', ['Ray Bradbury'])
# ('A MAN', ['Oriana Fallaci'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ('WHIP HAND', ['Dick Francis'])
# ('BACK BAY', ['William Martin'])
# ('FIRESTARTER', ['Stephen King'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('FANNY', ['Erica Jong'])
# ('THE ORIGIN', ['Irving Stone'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('THE SECOND COMING', ['Walker Percy'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('BACK BAY', ['William Martin'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE TRANSIT OF VENUS', ['Shirley Hazzard'])
# ('TRIPLE', ['Ken Follett'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('DOCTOR FISCHER OF GENEVA OR THE BOMB PARTY', ['Graham Greene'])
# ('MAN,  WOMAN AND CHILD', ['Erich Segal'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('TRIPLE', ['Ken Follett'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('MOVIOLA', ['Garson Kanin'])
# ('OLD LOVE', ['Isaac Bashevis Singer'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('THE CRADLE WILL FALL', ['Mary Higgins Clark'])
# ('THE SECOND COMING', ['Walker Percy'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('SOLO', ['Jack Higgins'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('MURDER IN THE WHITE HOUSE', ['Margaret Truman'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FIRESTARTER', ['Stephen King'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('THE ORIGIN', ['Irving Stone'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('THE RING', ['Danielle Steel'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('FANNY', ['Erica Jong'])
# ('THE OLD NEIGHBORHOOD', ['Avery Corman'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('TRIPLE', ['Ken Follett'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('FIRESTARTER', ['Stephen King'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('THE ORIGIN', ['Irving Stone'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('UNFINISHED TALES', ['J.R.R. Tolkien'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('MANCHU', ['Robert Elegant'])
# ('THE OLD NEIGHBORHOOD', ['Avery Corman'])
# ('THE HIDDEN TARGET', ['Helen MacInnes'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FIRESTARTER', ['Stephen King'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE ORIGIN', ['Irving Stone'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('FANNY', ['Erica Jong'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('TRIPLE', ['Ken Follett'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ('OLD LOVE', ['Isaac Bashevis Singer'])
# ('FIRESTARTER', ['Stephen King'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('THE ORIGIN', ['Irving Stone'])
# ('FANNY', ['Erica Jong'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('BELLEFLEUR', ['Joyce Carol Oates'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('MAN,  WOMAN AND CHILD', ['Erich Segal'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('DOCTOR FISCHER OF GENEVA OR THE BOMB PARTY', ['Graham Greene'])
# ('SOLO', ['Jack Higgins'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FIRESTARTER', ['Stephen King'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('UNFINISHED TALES', ['J.R.R. Tolkien'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('THE ORIGIN', ['Irving Stone'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE HIDDEN TARGET', ['Helen MacInnes'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('MANCHU', ['Robert Elegant'])
# ('THE OLD NEIGHBORHOOD', ['Avery Corman'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('TRIPLE', ['Ken Follett'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('THE DEAD ZONE', ['Stephen King'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ('MOVIOLA', ['Garson Kanin'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('FIRESTARTER', ['Stephen King'])
# ('FANNY', ['Erica Jong'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('THE ORIGIN', ['Irving Stone'])
# ('GREEN MONDAY', ['Michael M. Thomas'])
# ('BELLEFLEUR', ['Joyce Carol Oates'])
# ('THE CRADLE WILL FALL', ['Mary Higgins Clark'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('THE SECOND COMING', ['Walker Percy'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('SOLO', ['Jack Higgins'])
# ('THE CRADLE WILL FALL', ['Mary Higgins Clark'])
# ('MAN,  WOMAN AND CHILD', ['Erich Segal'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('FIRESTARTER', ['Stephen King'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('THE SECOND COMING', ['Walker Percy'])
# ('BELLEFLEUR', ['Joyce Carol Oates'])
# ('THE ORIGIN', ['Irving Stone'])
# ('MURDER IN THE WHITE HOUSE', ['Margaret Truman'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('GREEN MONDAY', ['Michael M. Thomas'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('TRIPLE', ['Ken Follett'])
# ('THE LAST ENCHANTMENT', ['Mary Stewart'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ('THE DEAD ZONE', ['Stephen King'])
# ('THE ESTABLISHMENT', ['Howard Fast'])
# ('THE TOP OF THE HILL', ['Irwin Shaw'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('THE GREEN RIPPER', ['John D. MacDonald'])
# ('THE THIRD WORLD WAR: August 1985', ['General Sir John Hackett', 'Other'])
# ('WAR AND REMEMBRANCE', ['Herman Wouk'])
# ("THERE'S NO SUCH PLACE AS FAR AWAY", ['Richard Bach'])
# ('SHADOW OF THE MOON', ['M.M. Kaye'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('FIRESTARTER', ['Stephen King'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('SOLO', ['Jack Higgins'])
# ('THE SECOND COMING', ['Walker Percy'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('BELLEFLEUR', ['Joyce Carol Oates'])
# ('GREEN MONDAY', ['Michael M. Thomas'])
# ('MURDER IN THE WHITE HOUSE', ['Margaret Truman'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('FIRESTARTER', ['Stephen King'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('FANNY', ['Erica Jong'])
# ('THE ORIGIN', ['Irving Stone'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('BELLEFLEUR', ['Joyce Carol Oates'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('GREEN MONDAY', ['Michael M. Thomas'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('FIRESTARTER', ['Stephen King'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FANNY', ['Erica Jong'])
# ('THE ORIGIN', ['Irving Stone'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('TRIPLE', ['Ken Follett'])
# ('MEMORIES OF ANOTHER DAY', ['Harold Robbins'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('JAILBIRD', ['Kurt Vonnegut'])
# ('THE DEAD ZONE', ['Stephen King'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ("THE EXECUTIONER'S SONG", ['Norman Mailler'])
# ('THE COVENANT', ['James A. Michener'])
# ('FIRESTARTER', ['Stephen King'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE ORIGIN', ['Irving Stone'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('FANNY', ['Erica Jong'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('THE RING', ['Danielle Steel'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('BACK BAY', ['William Martin'])
# ('WHIP HAND', ['Dick Francis'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('THE COVENANT', ['James A. Michener'])
# ('THE KEY TO REBECCA', ['Ken Follett'])
# ('FIRESTARTER', ['Stephen King'])
# ('LOON LAKE', ['E.L. Doctorow'])
# ('COME POUR THE WINE', ['Cynthia Freeman'])
# ('THE FIFTH HORSEMAN', ['Larry Collins', 'Dominique Lapierre'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('THE TENTH COMMANDMENT', ['Lawrence Sanders'])
# ('THE SECOND LADY', ['Irving Wallace'])
# ('THE HIDDEN TARGET', ['Helen MacInnes'])
# ('THE CLAN OF THE CAVE BEAR', ['Jean M. Auel'])
# ('THE RING', ['Danielle Steel'])
# ('MANCHU', ['Robert Elegant'])
# ('UNFINISHED TALES', ['J.R.R. Tolkien'])
# ('THE ORIGIN', ['Irving Stone'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ('WHIP HAND', ['Dick Francis'])
# ('BACK BAY', ['William Martin'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])
# ('THE BLEEDING HEART', ['Marilyn French'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('PORTRAITS', ['Cynthia Freeman'])
# ("SMILEY'S PEOPLE", ['John le Carr\xc3\xa9'])
# ("WHO'S ON FIRST", ['William F. Buckley Jr'])
# ("CREEK MARY'S BLOOD", ['Dee Brown'])
# ('BACK BAY', ['William Martin'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('HUNGRY AS THE SEA', ['Wilbur Smith'])
# ('RANDOM WINDS', ['Belva Plain'])
# ("SOPHIE'S CHOICE", ['William Styron'])
# ('RAGE OF ANGELS', ['Sidney Sheldon'])
# ('RANDOM WINDS', ['Belva Plain'])
# ('THE BOURNE IDENTITY', ['Robert Ludlum'])
# ('SINS OF THE FATHERS', ['Susan Howatch'])
# ('THE SPIKE', ['Arnaud de Borchgrave', 'Robert Moss'])
# ('PRINCESS DAISY', ['Judith Krantz'])
# ('THE NINJA', ['Eric Van Lustbader'])
# ('KANE & ABEL', ['Jeffrey Archer'])
# ('MURDER IN THE WHITE HOUSE', ['Margaret Truman'])
# ('THE SECOND COMING', ['Walker Percy'])
# ('INNOCENT BLOOD', ['P.D. James'])
# ('THE CRADLE WILL FALL', ['Mary Higgins Clark'])
# ('SOLO', ['Jack Higgins'])
# ('NO LOVE LOST', ['Helen Van Slyke'])
# ("THE DEVIL'S ALTERNATIVE", ['Frederick Forsyth'])

# %% [markdown]
# # To OCLC

# %%
import xml.etree.ElementTree
import json
import urllib2
import re

ta_to_data_dict = {} 
oclc_base = "http://classify.oclc.org/classify2/Classify?"
alph = re.compile('[^a-zA-Z]')
suffixes = ['CPA', 'CSC', 'CSJ', 'DC', 'DD', 'DDS', 'DMD', 'DO', 'DVM', 'EDD', 'ESQ', 'II', 'III', 
            'IV', 'INC', 'JD', 'JR', 'LLD', 'LTD', 'MD', 'OD', 'OSB', 'PC', 'PE', 'PHD', 'RET', 
            'RGS', 'RN', 'RNC', 'SHCJ', 'SJ', 'SNJM', 'SR', 'SSMO', 'USA', 'USAF', 'USAFR', 'USAR', 
            'USCG', 'USMC', 'USMCR', 'USN', 'USNR']

# %%
def suffix(phrase):
    norm_phrase = phrase.replace(',',"").upper()
    if norm_phrase in suffixes:
        return True
    else:
        return False
    
def strip_punct(text):
    return alph.sub('', text)

def norm_text(text):
    return strip_punct(text).lower()

def url_to_data(url,f):
    req = urllib2.Request(url)
    req.add_header('User-agent', 'Mozilla 5.10')
    res = urllib2.urlopen(req)
    if(f=="xml"):
        data = xml.etree.ElementTree.parse(res).getroot()
    if(f=="json"):
        data = json.load(res)
    return data

def convert_to_search(name):
    return_string = ""
    last_ch = " "
    for ch in name:
        if (ch == " "):
            if (last_ch != "."):
                return_string = return_string + "+"
        else:
            if ch == ".":
                return_string = return_string +".+"
            else:
                return_string = return_string+ch
        last_ch = ch
    return return_string

def last_name_recursive(name,last_index):
    if last_index == 0:
        return ""
    last_phrase = name[last_index]
    if not suffix(last_phrase):
        return last_phrase
    else:
        return last_name_recursive(name, last_index-1)

def last_name(name):
    names = name.split(" ")
    last_index = len(names)-1
    last = last_name_recursive(names,last_index)
    return last

def first_name(name):
    names = name.split(" ")
    return names[0]

# %%
from lxml import html
from bs4 import BeautifulSoup

viaf_base = "http://www.viaf.org/viaf/"
    
def get_gender_scrape(i):
    url = viaf_base+str(i)+"/"
    data = requests.get(url).text
    soup = BeautifulSoup(data,"lxml")
    personal = soup.find('div',{'id':'personalinfo'})
    h4s = personal.find('h4')
    if (h4s is None) or (len(h4s)<5):
        return ""
    mt = []
    i=0
    for h in h4s:
        mt.append(h)
        i = i+1
    return mt[4]
# Out:
# Male

# %%
def is_book(w,t,a):
    if "book" in norm_text(w.get("format")):
        if norm_text(t) in norm_text(w.get("title")):
            for auth in a:
                if last_name(norm_text(auth)) in norm_text(w.get("author")):
                    return True
    return False

def find_all_works(xml,title,authors):
    works = xml.find('{http://classify.oclc.org}works')
    if works is None:
        works = []
        works.append(xml.find('{http://classify.oclc.org}work'))
        if (works is None) or works == []:
            return []        
    books = []
    for w in works:
        if is_book(w,title,authors):
            owi = w.get("owi")
            holdings = w.get("holdings")
            try:
                lyr = w.get("lyr")
            except:
                lyr = ""
            books.append({"owi":owi,"holdings":holdings,"lyr":lyr})
    return books

def new_work(w, entries):
    for e in entries:
        if w['owi'] == e["owi"]:
             return False
    return True

def get_oclc_entries(title,authors):
    url = oclc_base +"title="+convert_to_search(title)
    i = 0
    entries = []
    for a in authors:
        auth_url = url +"&author=" + last_name(a)
        xml = url_to_data(auth_url,"xml")
        try:
            works = find_all_works(xml,title,authors)
        except:
            return []
        if entries == []:
            entries = works
        else:
            for w in works:
                if new_work(w,entries):
                    entries = entries.append(w)
    return entries
    
print get_oclc_entries('BELOVED', ['Toni Morrison']) 

def max_holding(oarr):
    target = oarr[0]
    for o in oarr[1:]:
        if int(o['holdings'])>int(target['holdings']):
            target = o
    return target

def get_authors(xml):
    authors = xml.find('{http://classify.oclc.org}authors')
    target = []
    for a in authors:
        text = a.text
        v = a.get('viaf')
        target.append({'name':text, 'viaf':v})
    return target

def get_fast(xml):
    recs = xml.find('{http://classify.oclc.org}recommendations')
    target = []
    if recs is not None:
        fast = recs.find('{http://classify.oclc.org}fast')
        if fast is not None:
            headings = fast.find('{http://classify.oclc.org}headings')
            for h in headings:
                target.append(h.text)
    return target

def lookup_oclc(owi):
    url = oclc_base+"owi="+owi
    xml = url_to_data(url,"xml")
    v = get_authors(xml)
    fast = get_fast(xml)
    target = {'authors':v,'fast':fast}
    return target

test_author_dict = [{'viaf': '22619695', 'name': 'Bailey, Charles Waldo, 1929-2012 [Author]'}, {'viaf': '19720195', 'name': 'Knebel, Fletcher'}]

def get_genders(authors, viaf_dict):
    target = []
    for a in authors:
        v = get_viaf(a,viaf_dict)
        gender = get_gender_scrape(v)
        target.append({"name":a,"viaf":v,"gender":gender})
    return target
    
def get_viaf(author, viaf_dict_arr):
    l = norm_text(last_name(author))
    f = norm_text(first_name(author))
    target = ""
    for v in viaf_dict_arr:
        if l in norm_text(v['name']):
            target = v['viaf']
            if f in norm_text(v['name']):
                return v['viaf']
    return target

#print(get_genders(["Fletcher Knebel","Charles W. Bailey II"],test_author_dict))
# Out:
# [{'holdings': '13357', 'owi': '989794', 'lyr': '1987'}, {'holdings': '1899', 'owi': '149526417', 'lyr': '1987'}, {'holdings': '982', 'owi': '3768430774', 'lyr': '1998'}, {'holdings': '159', 'owi': '839489420', 'lyr': '2002'}, {'holdings': '61', 'owi': '1151679152', 'lyr': '1970'}, {'holdings': '27', 'owi': '4020568630', 'lyr': '2003'}, {'holdings': '4', 'owi': '301075038', 'lyr': '2001'}, {'holdings': '4', 'owi': '3092748', 'lyr': '????'}, {'holdings': '1', 'owi': '3375545245', 'lyr': '1988'}, {'holdings': '1', 'owi': '866836700', 'lyr': '2008'}]

# %%
def process_input_data(ta):       
    # if str(ta) not in ta_to_oclc_dict: CHECK FOR THIS OUTSIDE THE FN
    title = ta[0]
    author = ta[1]
    oclc = get_oclc_entries(title,author)
    if (oclc is None) or (len(oclc)<1):
        owi = []
        holdings = []
        year_pub = []
        fast_subjects = set()
        genders = []
    else:
        if len(oclc) == 1:
            primary = oclc[0]
            primary_data = lookup_oclc(primary['owi'])
            fast_subjects = set(primary_data['fast'])
        else:
            primary = max_holding(oclc)
            primary_data = lookup_oclc(primary['owi'])
            fast_subjects = set(primary_data['fast'])
            for o in oclc:
                if o['owi'] != primary['owi']:
                    other_data = lookup_oclc(o['owi'])
                    fast_subjects.update(other_data['fast'])
        owi = primary["owi"]
        year_pub = primary["lyr"]
        genders = get_genders(author, primary_data['authors'])
    return {"owi": owi, "year_pub": year_pub, "fast_subjects":fast_subjects, "genders":genders}

## need to add the original data (date, year, rankings) if this is the ultimate output
def process_raw_list(input_ls):
    target = []
    for row in input_ls:
        ta = title_author_pair(row[2])
        target_row = {"date":row[0],"title":ta[0],"authors":ta[1]}
        string_ta = str(ta)
        if string_ta in ta_to_data_dict:
            target_row.update(ta_to_data_dict[string_ta])
        else:
            processed = process_input_data(ta)
            target_row.update(processed)
            ta_to_data_dict[string_ta] = processed
        target.append(target_row)
    return target

processed = process_raw_list(eighty)
print processed[0]
# Out:
# {'year_pub': '1979', 'owi': '463023', 'authors': ['John le Carr\xc3\xa9'], 'date': datetime.datetime(1980, 2, 3, 0, 0), 'genders': [{'gender': u'Male', 'viaf': '109254932', 'name': 'John le Carr\xc3\xa9'}], 'title': "SMILEY'S PEOPLE", 'fast_subjects': set(['Smiley, George (Fictitious character)', 'Intelligence officers', 'Spy stories, English', 'Radio plays, English', 'Fiction', 'Intelligence service', 'Secret service', 'Adventure stories', 'English fiction', 'Great Britain', 'Radio plays', 'Spy stories'])}

# %%
import pandas

terms = []
for x in processed:
    for y in x['fast_subjects']:
        if genre_candidate(y):
            terms.append(y)
    
term_series = pandas.Series(terms)
counts = term_series.value_counts()
print len(processed)
print(counts)
# Out:
# 780
# American fiction                           175
# Spy stories                                141
# English fiction                            138
# Adventure stories                          137
# Detective and mystery stories               88
# Romance fiction                             75
# Fiction                                     69
# American literature                         54
# Political fiction                           45
# Suspense fiction                            40
# Domestic fiction                            38
# Horror tales                                34
# Paranormal fiction                          34
# Spy stories, American                       33
# Suspense fiction, American                  33
# English literature                          32
# Historical fiction                          30
# Legal stories                               27
# Regimental histories                        26
# Railroad stories                            26
# Spy stories, English                        26
# War stories                                 22
# Detective and mystery stories, English      21
# Literature                                  17
# Fantasy fiction                             16
# Horror tales, American                      15
# Religious fiction                           14
# Fiction--Authorship                         13
# Historical fiction, American                13
# Sea stories                                 10
# South African fiction                       10
# Spanish fiction                              9
# French American fiction                      7
# Detective and mystery stories, American      7
# Psychological fiction                        7
# Fantasy fiction, English                     6
# Short stories                                5
# Short stories, English                       4
# Science fiction, American                    3
# Science fiction                              2
# Short stories, American                      1
# Fantasy fiction, American                    1
# Adventure stories, American                  1
# dtype: int64

# %%
genre_terms = ["fiction","stories","tales","literature","opera"]
genre_dict = {"romance":{"keys":["romance","love","erotic","domestic"],"stops":["language"]},
              "suspense":{"keys":["suspense"]},
              "horror":{"keys":["horror","paranormal"]},
              "mystery":{"keys":["mystery","detective","crime"]},
              "spy_and_politics":{"keys":["spy","politic","war"]},
              "fsf":{"keys":["fantasy","science fiction", "space","cyberpunk","steampunk"]},
              "adventure":{"keys":["adventure","western","sea"]},
              "ya":{"keys":["young adult"]},
              "religious":{"keys":["religious","christian"],"stop":["aspects"]},
              "historical":{"keys":["historical"]} ## <-- I think this one might not be a well-supported
                                                   ## category in the DB
            }

def genre_candidate(fast_term):
    for term in genre_terms:
        if term in norm_text(fast_term):
            return True
    return False

def is_genre(fast_term,genre_str):
    terms = genre_dict[genre_str]['keys']
    if 'stops' in genre_dict[genre_str]:
        stops=genre_dict[genre_str]['stops']
    else:
        stops = []
    target = False
    for term in terms:
        if term in norm_text(fast_term):
            target = True
    for stop in stops:
        if stop in norm_text(fast_term):
            target = False
    return target

def classify_genre(processed_row):
    subjects = processed_row['fast_subjects']
    target = {}
    for genre in genre_dict:
        target[genre]=0
    for subject in subjects:
        if genre_candidate(subject):
            for genre in genre_dict:
                if is_genre(subject,genre):
                    target[genre] = 1
    return target

def tally_genres(cl_ls):
    counts_dict = {}
    for genre in genre_dict:
        counts_dict[genre] = 0
    for x in cl_ls:
        for genre in genre_dict:
            counts_dict[genre] = counts_dict[genre]+x[genre]
    return counts_dict

classified = []
for x in processed:
    classified.append(classify_genre(x))
print tally_genres(classified)
      
test_group = df.groupby(["date"])
print len(test_group)
for x in test_group:
    for y in x[1]:
        cl
    
def tally_genres_by_week(cl_ls):
    df = pandas.DataFrame(cl_ls)
    grouped = df.groupby(["date"])
    target = []
    for group in grouped:
        classified = []
        date = group[0]
        entry_dict = group[1]
        classified.append(classify_genre(entry_dict))
        tallied = tally_genres(classified)
        tallied["date"] = date
        target.append(tallied)
    return target
    
tall_df = pandas.DataFrame(tally_genres_by_week(processed))
print tall_df
# Out:
# {'mystery': 89, 'fsf': 17, 'ya': 0, 'horror': 34, 'spy_and_politics': 179, 'romance': 96, 'suspense': 40, 'adventure': 137, 'historical': 43, 'religious': 14}
# 52
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-9a8772d8291a> in <module>()
#      77     return target
#      78
# ---> 79 tall_df = pandas.DataFrame(tally_genres_by_week(processed))
#      80 print tall_df
#
# <ipython-input-192-9a8772d8291a> in tally_genres_by_week(cl_ls)
#      71         date = group[0]
#      72         entry_dict = group[1]
# ---> 73         classified.append(classify_genre(entry_dict))
#      74         tallied = tally_genres(classified)
#      75         tallied["date"] = date
#
# <ipython-input-192-9a8772d8291a> in classify_genre(processed_row)
#      40         target[genre]=0
#      41     for subject in subjects:
# ---> 42         if genre_candidate(subject):
#      43             for genre in genre_dict:
#      44                 if is_genre(subject,genre):
#
# <ipython-input-192-9a8772d8291a> in genre_candidate(fast_term)
#      15 def genre_candidate(fast_term):
#      16     for term in genre_terms:
# ---> 17         if term in norm_text(fast_term):
#      18             return True
#      19     return False
#
# <ipython-input-93-8fb93c82755d> in norm_text(text)
#      10
#      11 def norm_text(text):
# ---> 12     return strip_punct(text).lower()
#      13
#      14 def url_to_data(url,f):
#
# <ipython-input-93-8fb93c82755d> in strip_punct(text)
#       7
#       8 def strip_punct(text):
# ----> 9     return alph.sub('', text)
#      10
#      11 def norm_text(text):
#
# TypeError: expected string or buffer

# %%
# Out:
# {'COME POUR THE WINE,  $12.95.) A': 'COME POUR THE WINE', 'THE CRADLE WILL FALL,  $10.95.) A': 'THE CRADLE WILL FALL', 'Norman Mailler': 'Norman Mailer', 'THE TENTH COMMANDMENT,  $11.95.) A': 'THE TENTH COMMANDMENT', 'THE SECOND COMING,  $12.95.) A': 'THE SECOND COMING'}
